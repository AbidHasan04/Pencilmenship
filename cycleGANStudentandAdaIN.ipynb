.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/232133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2330133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/234133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2382133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2383133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2387133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2390133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2396133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2400133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2426133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2442133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2444133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2445133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2464133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2490133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2517133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2542133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2548133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2558133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2562133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2571133.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0133/2577133.png
# ...
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1135150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1137150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1149150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1160150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1176150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1186150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1204150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1209150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1217150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1225150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1232150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1251150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1257150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1275150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1278150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1281150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1285150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1289150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1292150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1297150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1302150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1311150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1323150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1327150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/134150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1357150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1360150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1362150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1381150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1406150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1408150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1409150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1428150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1451150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/145150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1460150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1483150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1493150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1504150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1509150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1510150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1514150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1517150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1519150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1531150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/153150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1542150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1545150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1548150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1559150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1572150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1612150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1622150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1624150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1626150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1630150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1660150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1666150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1675150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1677150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1688150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1701150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1721150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/172150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1732150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1737150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1739150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1743150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1747150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1756150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1768150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1774150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1789150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1796150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1804150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1820150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1823150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1828150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1836150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1838150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1839150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1854150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1864150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1914150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1918150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1936150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1937150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1962150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/1978150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2004150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2009150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2014150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2016150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2037150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2046150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2072150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2087150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/209150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2094150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2099150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2102150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2106150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2107150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2121150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2129150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2133150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/214150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2154150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2157150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2162150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2167150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2185150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2216150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2220150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2241150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2242150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2256150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2266150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2268150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2313150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2328150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2374150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2387150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2388150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2389150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2399150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2406150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2409150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2422150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2424150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2430150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2435150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2444150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2445150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2449150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2470150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2472150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2476150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2477150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2515150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2535150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2542150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2543150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2549150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2562150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2565150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2571150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2572150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2577150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2588150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2597150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2608150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2612150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2616150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2626150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2650150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2661150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2665150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2678150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2684150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2685150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2686150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2689150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2692150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2700150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2714150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2718150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2722150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2748150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2755150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2762150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2799150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2828150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2836150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2842150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2848150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2849150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2851150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2869150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2870150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2873150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2877150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2892150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2894150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2914150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2919150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2933150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2938150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2946150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2964150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2968150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/2970150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/351150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/35150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/39150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/395150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/440150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/448150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/474150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/476150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/503150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/506150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/51150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/529150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/534150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/572150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/573150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/577150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/581150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/594150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/609150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/610150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/642150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/721150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/728150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/757150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/766150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/771150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/778150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/786150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/792150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/796150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/805150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/810150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/852150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/876150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/885150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/888150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/890150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/903150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/916150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/933150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/947150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/958150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/974150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/975150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/985150.png
#   inflating: danbooru-sketch-pair-128x/gray/src/0150/990150.png

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import os
from torchvision import transforms
import matplotlib.pyplot as plt

from PIL import Image

import numpy as np
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
import torch.nn.functional as F

# %%
class AdaIN(nn.Module):
    def __init__(self, epsilon=1e-5):
        super(AdaIN, self).__init__()
        self.epsilon = epsilon

    def forward(self, content_features, style_features):
        # mean and variance for CONTENT and STYLE
        mean_content = content_features.mean(dim=[2, 3], keepdim=True)
        std_content = content_features.std(dim=[2, 3], keepdim=True) + self.epsilon
        mean_style = style_features.mean(dim=[2, 3], keepdim=True)
        std_style = style_features.std(dim=[2, 3], keepdim=True) + self.epsilon

        # Normalize
        normalized_features = (content_features - mean_content) / std_content
        stylized_features = (normalized_features * std_style) + mean_style

        return stylized_features

# %% [markdown]
# class ImageFullDataset(Dataset):
#     def __init__(self, root_dir, transform=None):
#         self.painting_dir = os.path.join(root_dir, 'color/src/0002')
#         self.sketch_dir = os.path.join(root_dir, 'color/sketch/0002')
#         self.painting_files = sorted(os.listdir(self.painting_dir))
#         self.sketch_files = sorted(os.listdir(self.sketch_dir))
#         self.transform = transform
#
#     def __len__(self):
#         return len(self.painting_files)
#
#     def __getitem__(self, idx):
#         # Load the full image and sketch
#         painting_path = os.path.join(self.painting_dir, self.painting_files[idx])
#         sketch_path = os.path.join(self.sketch_dir, self.sketch_files[idx])
#         painting = Image.open(painting_path).convert('RGB')
#         sketch = Image.open(sketch_path).convert('RGB')
#
#         # Apply transformations if any
#         if self.transform:
#             painting = self.transform(painting)
#             sketch = self.transform(sketch)
#
#         return {'painting': painting, 'sketch': sketch}
#
#
# transform = transforms.Compose([
# transforms.Resize((64, 64)),
# transforms.ToTensor(),
# transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
# ])
#
# dataset = ImageFullDataset(root_dir="/content/danbooru-sketch-pair-128x", transform=transform)
# dataloader = DataLoader(dataset, batch_size= 64, shuffle=True)

# %%
class ImageFullDataset(Dataset):
    def __init__(self, root_dir, transform=None, dirs=['0001', '0002', '0006', '0007', '0008', '0009', '0010']):
        self.root_dir = root_dir
        self.transform = transform
        self.dirs = dirs
        self.datasets = []

        for dir in dirs:
            painting_dir = os.path.join(root_dir, 'color/src', dir)
            sketch_dir = os.path.join(root_dir, 'color/sketch', dir)
            painting_files = sorted(os.listdir(painting_dir))
            sketch_files = sorted(os.listdir(sketch_dir))
            self.datasets.append({
                'painting_dir': painting_dir,
                'sketch_dir': sketch_dir,
                'painting_files': painting_files,
                'sketch_files': sketch_files
            })

    def __len__(self):
        return sum(len(dataset['painting_files']) for dataset in self.datasets)

    def __getitem__(self, idx):
        # Determine which dataset to use based on the index
        dataset_idx = 0
        total_len = 0
        while idx >= total_len:
            total_len += len(self.datasets[dataset_idx]['painting_files'])
            dataset_idx += 1

        dataset_idx -= 1
        painting_idx = idx - total_len + len(self.datasets[dataset_idx]['painting_files']) - 1

        # Load the full image and sketch
        painting_path = os.path.join(self.datasets[dataset_idx]['painting_dir'], self.datasets[dataset_idx]['painting_files'][painting_idx])
        sketch_path = os.path.join(self.datasets[dataset_idx]['sketch_dir'], self.datasets[dataset_idx]['sketch_files'][painting_idx])
        painting = Image.open(painting_path).convert('RGB')
        sketch = Image.open(sketch_path).convert('RGB')

        # Apply transformations if any
        if self.transform:
            painting = self.transform(painting)
            sketch = self.transform(sketch)

        return {'painting': painting, 'sketch': sketch}


transform = transforms.Compose([
transforms.Resize((64, 64)),
transforms.ToTensor(),
transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

dataset = ImageFullDataset(root_dir="/content/danbooru-sketch-pair-128x", transform=transform)
dataloader = DataLoader(dataset, batch_size= 64, shuffle=True)

# %% [markdown]
# ##Building BLOCKS

# %%
sharpening_filter = torch.tensor([
    [0, -1, 0],
    [-1, 5, -1],
    [0, -1, 0]
], dtype=torch.float32)

point_spread_filter = torch.tensor([
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9],
    [1/9, 1/9, 1/9]
], dtype=torch.float32)

gradient_north_filter = torch.tensor([
    [1, 1, 1],
    [0, 0, 0],
    [-1, -1, -1]
], dtype=torch.float32)

gradient_north_east_filter = torch.tensor([
    [0, 1, 1],
    [-1, 0, 1],
    [-1, -1, 0]
], dtype=torch.float32)

gradient_north_west_filter = torch.tensor([
    [1, 1, 0],
    [1, 0, -1],
    [0, -1, -1]
], dtype=torch.float32)

gradient_south_filter = torch.tensor([
    [-1, -1, -1],
    [0, 0, 0],
    [1, 1, 1]
], dtype=torch.float32)

gradient_west_filter = torch.tensor([
    [1, 0, -1],
    [1, 0, -1],
    [1, 0, -1]
], dtype=torch.float32)

# Create a function to apply a custom filter
class CustomFilterLayer(nn.Module):
    def __init__(self, kernel):
        super(CustomFilterLayer, self).__init__()
        self.kernel = kernel.view(1, 1, 3, 3)  # Reshape kernel for 2D conv

    def forward(self, x):
        # Ensure input is in the correct shape (Batch, Channels, Height, Width)
        return F.conv2d(x, self.kernel, padding=1)  # Apply convolution with padding

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, down=True, use_act=True, **kwargs):
        super().__init__()
        if 'kernel_size' not in kwargs: kwargs['kernel_size'] = 3 # ~!!!!Default kernel size if 'padding' not in kwargs: kwargs['padding'] = 1 # Default padding
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, padding_mode='reflect', **kwargs) if down
            else nn.ConvTranspose2d(in_channels, out_channels, **kwargs),
            nn.InstanceNorm2d(out_channels),
            nn.ReLU(inplace=True) if use_act else nn.Identity()
        )

    def forward(self, x):
        return self.conv(x)




class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            ConvBlock(channels, channels, kernel_size=3, padding=1),
            ConvBlock(channels, channels, use_act=False, kernel_size=3, padding=1)
        )

    def forward(self, x):
        return x + self.block(x)

# %%
class GeneratorTeach(nn.Module):
    def __init__(self, img_channels, num_residuals=9, num_features=64):
        super().__init__()

        #encoder
        self.initial = nn.Sequential(
            nn.Conv2d(img_channels, num_features, kernel_size=7, stride=1, padding=3, padding_mode="reflect"),
            nn.ReLU(inplace=True)
        )
        self.down_blocks = nn.ModuleList([
            ConvBlock(num_features, num_features * 2, kernel_size=3, stride=2, padding=1),
            ConvBlock(num_features * 2, num_features * 4, kernel_size=3, stride=2, padding=1)
        ])


        self.adain = AdaIN()

        #decoder
        self.residual_blocks = nn.Sequential(*[ResidualBlock(num_features * 4) for _ in range(num_residuals)])
        self.up_blocks = nn.ModuleList([
            ConvBlock(num_features * 4, num_features * 2, down=False, kernel_size=3, stride=2, padding=1, output_padding=1),
            ConvBlock(num_features * 2, num_features, down=False, kernel_size=3, stride=2, padding=1, output_padding=1)
        ])
        self.lastBlock = nn.Conv2d(num_features, img_channels, kernel_size=7, stride=1, padding=3, padding_mode="reflect")










    def forward(self, x, style_image):
        # Process both x and style_image through the initial layer
        x = self.initial(x)
        style_features = self.initial(style_image)  # Process style_image through the same initial layer

        # Downsample content and style features
        for layer in self.down_blocks:
            x = layer(x)
            style_features = layer(style_features)

       # print("x shape after downsampling:", x.shape)
        #print("style_features shape after downsampling:", style_features.shape)

        # Apply AdaIN
        x = self.residual_blocks(x)
        x = self.adain(x, style_features)

       # for filter_name in self.filters.keys():
        #  x = self.apply_filter(x, filter_name)  # Apply the current filter



        # Upsampling
        for layer in self.up_blocks:
            x = layer(x)

        return torch.tanh(self.lastBlock(x))

# %%
class Discriminator(nn.Module):
    def __init__(self, in_channels=3, features=[64, 128, 256, 512]):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(in_channels, features[0], kernel_size=4, stride=2, padding=1, padding_mode="reflect"),
            nn.LeakyReLU(0.2)
        )
        layers = []
        in_channels = features[0]
        for feature in features[1:]:
            layers.append(ConvBlock(in_channels, feature, stride=1 if feature == features[-1] else 2))
            in_channels = feature
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        x = self.initial(x)
        return torch.sigmoid(self.model(x))

# %% [markdown]
# #Student

# %%
class GeneratorStudent(nn.Module):
    def __init__(self, img_channels, num_residuals=6, num_features=32):
        super().__init__()
        self.initial = nn.Sequential(
            nn.Conv2d(img_channels, num_features, kernel_size=7, stride=1, padding=3, padding_mode="reflect"),
            nn.ReLU(inplace=True)
        )
        self.down_blocks = nn.ModuleList([
            ConvBlock(num_features, num_features * 2, kernel_size=3, stride=2, padding=1),
            ConvBlock(num_features * 2, num_features * 4, kernel_size=3, stride=2, padding=1)
        ])


        self.adain = AdaIN()
        self.residual_blocks = nn.Sequential(*[ResidualBlock(num_features * 4) for _ in range(num_residuals)])
        self.up_blocks = nn.ModuleList([
            ConvBlock(num_features * 4, num_features * 2, down=False, kernel_size=3, stride=2, padding=1, output_padding=1),
            ConvBlock(num_features * 2, num_features, down=False, kernel_size=3, stride=2, padding=1, output_padding=1)
        ])
        self.lastBlock = nn.Conv2d(num_features, img_channels, kernel_size=7, stride=1, padding=3, padding_mode="reflect")


    def forward(self, x, style_image):

        x = self.initial(x)
        style_features = self.initial(style_image)

        # Downsample content and style features
        for layer in self.down_blocks:
            x = layer(x)
            style_features = layer(style_features)

       # print("x shape after downsampling:", x.shape)
        #print("style_features shape after downsampling:", style_features.shape)

        #AdaIN
        x = self.adain(x, style_features)
        x = self.residual_blocks(x)

        # Upsampling
        for layer in self.up_blocks:
            x = layer(x)

        return torch.tanh(self.lastBlock(x))

# %%
#device ='cpu'
device = torch.device("cuda")
G = GeneratorTeach(3).to(device)
G_sketch = GeneratorTeach(3).to(device)

DA = Discriminator(3).to(device)
DB = Discriminator(3).to(device)

opt_G = optim.Adam(G.parameters(), lr=0.0008, betas=(0.5, 0.999))
opt_G_sketch = optim.Adam(G_sketch.parameters(), lr=0.0008, betas=(0.5, 0.999))

opt_DA = optim.Adam(DA.parameters(), lr=0.0008, betas=(0.5, 0.999))
opt_DB = optim.Adam(DB.parameters(), lr=0.0008, betas=(0.5, 0.999))

adversarial_loss = nn.MSELoss()

cycle_loss = nn.L1Loss()
identity_loss = nn.L1Loss()
feature_matching_loss = nn.L1Loss()

# %%
def save_checkpoint(epoch, G, G_sketch, DA, DB, opt_F, opt_G_sketch, opt_DA, opt_DB, path):
    checkpoint = {
        'epoch': epoch,
        'G_state_dict': G.state_dict(),
        'G_sketch_state_dict': G_sketch.state_dict(),

        'Discriminator_A_state_dict': DA.state_dict(),
        'Discriminator_B_state_dict': DB.state_dict(),

        'optimizer_G_state_dict': opt_G.state_dict(),
        'optimizer_G_sketch_state_dict': opt_G_sketch.state_dict(),

        'optimizer_DA_state_dict': opt_DA.state_dict(),
        'optimizer_DB_state_dict': opt_DB.state_dict(),
    }
    torch.save(checkpoint, path)
    print(f"Checkpoint saved for epoch {epoch}.")

# %%
def load_checkpoint( G, G_sketch, DA, DB, opt_F, opt_G_sketch, opt_DA, opt_DB, path):
    checkpoint = torch.load(path)
    G.load_state_dict(checkpoint['G_state_dict'])
    G_sketch.load_state_dict(checkpoint['G_sketch_state_dict'])

    DA.load_state_dict(checkpoint['Discriminator_A_state_dict'])
    DB.load_state_dict(checkpoint['Discriminator_B_state_dict'])

    opt_G.load_state_dict(checkpoint['optimizer_G_state_dict'])
    opt_G_sketch.load_state_dict(checkpoint['optimizer_G_sketch_state_dict'])

    opt_DA.load_state_dict(checkpoint['optimizer_DA_state_dict'])
    opt_DB.load_state_dict(checkpoint['optimizer_DB_state_dict'])
    start_epoch = checkpoint['epoch']   # Resume from the next epoch
    print(f"Checkpoint loaded. Resuming from epoch {start_epoch+1}.")
    return start_epoch+1

# %%
start_epoch = 0
num_epochs = 100  # Set your desired number of epochs
lambda_cycle = 18  # Weight for cycle consistency loss
lambda_identity = 0.55  # Weight for identity loss
lambda_feature_matching = 2 # Adjust as necessary
#try:
 #   start_epoch = load_checkpoint(G, G_sketch, DA, DB, opt_G, opt_G_sketch, opt_DA, opt_DB, "/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_83.pth")
#except FileNotFoundError:
 #   print("Checkpoint not found. Starting training from epoch 0.")
for epoch in range(start_epoch, num_epochs):



    for batch in dataloader:
        painting = batch['painting'].to(device)
        sketch = batch['sketch'].to(device)

        # === Train Generators ===
        # Identity loss
        # G(painting) should be close to painting if painting is fed as input
        identity_painting = G(painting, sketch)
        loss_identity_painting = identity_loss(identity_painting, painting) * lambda_identity

        # G_sketch(sketch) should be close to sketch if sketch is fed as input
        identity_sketch = G_sketch(sketch, painting)
        loss_identity_sketch = identity_loss(identity_sketch, sketch) * lambda_identity

        # Adversarial loss
        fake_sketch = G(painting, sketch)
        pred_fake_sketch = DB(fake_sketch)
        loss_G_adv = adversarial_loss(pred_fake_sketch, torch.ones_like(pred_fake_sketch))

        fake_painting = G_sketch(sketch, painting)
        pred_fake_painting = DA(fake_painting)
        loss_F_adv = adversarial_loss(pred_fake_painting, torch.ones_like(pred_fake_painting))

        # Cycle consistency loss
        reconstructed_painting = G_sketch(fake_sketch, fake_painting)
        loss_cycle_painting = cycle_loss(reconstructed_painting, painting) * lambda_cycle

        reconstructed_sketch = G(fake_painting, fake_sketch)
        loss_cycle_sketch = cycle_loss(reconstructed_sketch, sketch) * lambda_cycle


        real_features = DA(sketch)
        fake_features = DB(fake_sketch)
        loss_feature_matching = feature_matching_loss(real_features, fake_features) * lambda_feature_matching


        # Total generator loss
        loss_G_total = loss_identity_painting + loss_identity_sketch + loss_G_adv + loss_F_adv + loss_cycle_painting + loss_cycle_sketch + loss_feature_matching

           # Clear gradients for the optimizers
        opt_G.zero_grad()
        opt_G_sketch.zero_grad()

        # Backpropagate total loss
        loss_G_total.backward()
        opt_G.step()
        opt_G_sketch.step()
        #xm.optimizer_step(opt_G)
        #xm.optimizer_step(opt_G_sketch)



        pred_real_painting = DA(painting)
        loss_DA_real = adversarial_loss(pred_real_painting, torch.ones_like(pred_real_painting))

        # Fake loss for DA
        pred_fake_painting = DA(fake_painting.detach())  # Detach to avoid updating G_sketch
        loss_DA_fake = adversarial_loss(pred_fake_painting, torch.zeros_like(pred_fake_painting))

        # Total loss for DA
        loss_DA = (loss_DA_real + loss_DA_fake) * 0.5

        # Real loss for DB
        pred_real_sketch = DB(sketch)
        loss_DB_real = adversarial_loss(pred_real_sketch, torch.ones_like(pred_real_sketch))

        # Fake loss for DB
        pred_fake_sketch = DB(fake_sketch.detach())  # Detach to avoid updating G
        loss_DB_fake = adversarial_loss(pred_fake_sketch, torch.zeros_like(pred_fake_sketch))

        # Total loss for DB
        loss_DB = (loss_DB_real + loss_DB_fake) * 0.5

        # Clear gradients for the discriminator optimizers
        opt_DA.zero_grad()
        opt_DB.zero_grad()

        # Backpropagate discriminator losses and update
        loss_DA.backward()
        opt_DA.step()
        #xm.optimizer_step(opt_DA)

        loss_DB.backward()
        opt_DB.step()
        #xm.optimizer_step(opt_DB)

        #m.save({
         #   'epoch': epoch,
            #'model_state_dict_G': G.state_dict(),
          #  'model_state_dict_G_sketch': G_sketch.state_dict(),
           # 'optimizer_state_dict_G': opt_G.state_dict(),
            #'optimizer_state_dict_G_sketch': opt_G_sketch.state_dict(),
            #'loss': loss_G_total,
            #'model_state_dict_DA': DA.state_dict(),
            #'model_state_dict_DB': DB.state_dict(),
            #'optimizer_state_dict_DA': opt_DA.state_dict(),
            #'optimizer_state_dict_DB': opt_DB.state_dict(),
            #'loss_DA': loss_DA,
            #'loss_DB': loss_DB
        #}, f"/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_{epoch}.pth")


        save_checkpoint(epoch, G, G_sketch, DA, DB, opt_G, opt_G_sketch, opt_DA, opt_DB, "/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_{}.pth".format(epoch))
        print(f"Epoch [{epoch}/{num_epochs}], Loss G_Total: {loss_G_total.item()}, Loss DA: {loss_DA.item()}, Loss DB: {loss_DB.item()}")

    print(f'Batch {batch} done')
print('Training done')
# Out:
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 22.625713348388672, Loss DA: 0.2717478573322296, Loss DB: 0.27250322699546814
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 18.362173080444336, Loss DA: 0.27152806520462036, Loss DB: 0.2712097465991974
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 17.08228302001953, Loss DA: 0.2697125971317291, Loss DB: 0.2643386721611023
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 16.291065216064453, Loss DA: 0.26512426137924194, Loss DB: 0.259147047996521
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 15.933320999145508, Loss DA: 0.26341819763183594, Loss DB: 0.2577507495880127
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 14.857101440429688, Loss DA: 0.26246488094329834, Loss DB: 0.25508999824523926
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 14.665380477905273, Loss DA: 0.2587072253227234, Loss DB: 0.2564089894294739
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 14.21365737915039, Loss DA: 0.25971880555152893, Loss DB: 0.25770843029022217
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 13.947953224182129, Loss DA: 0.2593080997467041, Loss DB: 0.2558806240558624
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 14.192256927490234, Loss DA: 0.25836992263793945, Loss DB: 0.25344961881637573
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 13.762740135192871, Loss DA: 0.25522327423095703, Loss DB: 0.2590709328651428
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 13.235608100891113, Loss DA: 0.2606794536113739, Loss DB: 0.25384220480918884
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 12.50106143951416, Loss DA: 0.2620014548301697, Loss DB: 0.2552450895309448
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 11.563024520874023, Loss DA: 0.2593540847301483, Loss DB: 0.25757160782814026
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 11.477170944213867, Loss DA: 0.25862354040145874, Loss DB: 0.25386160612106323
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 11.6299467086792, Loss DA: 0.2612759470939636, Loss DB: 0.2534124553203583
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 11.556706428527832, Loss DA: 0.2638908922672272, Loss DB: 0.25028833746910095
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 12.39297866821289, Loss DA: 0.2606462240219116, Loss DB: 0.25656643509864807
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 10.519946098327637, Loss DA: 0.2594085931777954, Loss DB: 0.25495219230651855
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total: 10.565876007080078, Loss DA: 0.2583610415458679, Loss DB: 0.2555643320083618
# Checkpoint saved for epoch 0.
# Epoch [0/100], Loss G_Total:
# Checkpoint saved for epoch 1.
# Epoch [1/100], Loss G_Total: 5.851621150970459, Loss DA: 0.24335452914237976, Loss DB: 0.23590625822544098
# Checkpoint saved for epoch 1.
# Epoch [1/100], Loss G_Total: 5.880824565887451, Loss DA: 0.2439376264810562, Loss DB: 0.23782770335674286
# Checkpoint saved for epoch 1.
# Epoch [1/100], Loss G_Total: 6.088579177856445, Loss DA: 0.24287444353103638, Loss DB: 0.2373920977115631
# Checkpoint saved for epoch 1.
# Epoch [1/100], Loss G_Total: 5.904593467712402, Loss DA: 0.2421746701002121, Loss DB: 0.23658303916454315
# Checkpoint saved for epoch 1.
# Epoch [1/100], Loss G_Total: 5.554177761077881, Loss DA: 0.2422444075345993, Loss DB: 0.23450493812561035
# Checkpoint saved for epoch 1.
# ...
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           ...,
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#           [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000]]]]), 'sketch': tensor([[[[0.9922, 0.9922, 0.9922,  ..., 1.0000, 1.0000, 0.9922],
#           [0.9059, 0.9059, 0.9059,  ..., 0.9059, 0.9059, 0.8980],
#           [0.6941, 0.6784, 0.6706,  ..., 0.6549, 0.6471, 0.6549],
#           ...,
#           [0.6941, 0.7098, 0.7098,  ..., 0.6941, 0.6941, 0.7020],
#           [0.8667, 0.8824, 0.8824,  ..., 0.8824, 0.8824, 0.8824],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 1.0000, 1.0000]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 1.0000, 1.0000, 0.9922],
#           [0.9059, 0.9059, 0.9059,  ..., 0.9059, 0.9059, 0.8980],
#           [0.6941, 0.6784, 0.6706,  ..., 0.6549, 0.6471, 0.6549],
#           ...,
#           [0.6941, 0.7098, 0.7098,  ..., 0.6941, 0.6941, 0.7020],
#           [0.8667, 0.8824, 0.8824,  ..., 0.8824, 0.8824, 0.8824],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 1.0000, 1.0000]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 1.0000, 1.0000, 0.9922],
#           [0.9059, 0.9059, 0.9059,  ..., 0.9059, 0.9059, 0.8980],
#           [0.6941, 0.6784, 0.6706,  ..., 0.6549, 0.6471, 0.6549],
#           ...,
#           [0.6941, 0.7098, 0.7098,  ..., 0.6941, 0.6941, 0.7020],
#           [0.8667, 0.8824, 0.8824,  ..., 0.8824, 0.8824, 0.8824],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 1.0000, 1.0000]]],
#
#
#         [[[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]]],
#
#
#         [[[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]]],
#
#
#         ...,
#
#
#         [[[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]]],
#
#
#         [[[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]]],
#
#
#         [[[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]],
#
#          [[0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           ...,
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922],
#           [0.9922, 0.9922, 0.9922,  ..., 0.9922, 0.9922, 0.9922]]]])} done
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.939692974090576, Loss DA: 0.24016883969306946, Loss DB: 0.23414874076843262
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.859985828399658, Loss DA: 0.2407504916191101, Loss DB: 0.2372177541255951
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.998490333557129, Loss DA: 0.24275095760822296, Loss DB: 0.23571962118148804
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.815527439117432, Loss DA: 0.23996660113334656, Loss DB: 0.23486313223838806
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.707866191864014, Loss DA: 0.23948659002780914, Loss DB: 0.23440590500831604
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.700525760650635, Loss DA: 0.239328533411026, Loss DB: 0.23634441196918488
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.852389335632324, Loss DA: 0.24034669995307922, Loss DB: 0.2350577414035797
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.615534782409668, Loss DA: 0.2371557056903839, Loss DB: 0.23497390747070312
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.642348766326904, Loss DA: 0.23960180580615997, Loss DB: 0.2340991050004959
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4.719700336456299, Loss DA: 0.24010372161865234, Loss DB: 0.233291357755661
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 5.216099262237549, Loss DA: 0.23961147665977478, Loss DB: 0.23520180583000183
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 5.227529525756836, Loss DA: 0.23847976326942444, Loss DB: 0.23220625519752502
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 5.2495880126953125, Loss DA: 0.23887571692466736, Loss DB: 0.23340186476707458
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 5.0723137855529785, Loss DA: 0.2378527820110321, Loss DB: 0.23376569151878357
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 5.475090980529785, Loss DA: 0.23922201991081238, Loss DB: 0.2369452714920044
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 4
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 6.268232822418213, Loss DA: 0.24120309948921204, Loss DB: 0.24022236466407776
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 6.436808109283447, Loss DA: 0.24076378345489502, Loss DB: 0.23873481154441833
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 6.638952255249023, Loss DA: 0.24285969138145447, Loss DB: 0.23946073651313782
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 6.669817924499512, Loss DA: 0.24014997482299805, Loss DB: 0.24292536079883575
# Checkpoint saved for epoch 2.
# Epoch [2/100], Loss G_Total: 6.639848232269287, Loss DA: 0.2414495348930359, Loss DB: 0.2367100715637207

# %% [markdown]
# ##StudentTraining

# %%
distillation_loss = nn.MSELoss()
distillation_loss2 = nn.KLDivLoss()
lambda_distill = 10

# %%
#G_teacher = GeneratorTeach(3).to(device)
G.load_state_dict(torch.load("/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_11.pth")['G_state_dict'])
G.eval()  # Set to evaluation mode to prevent gradients from being computed

# Initialize student model, discriminators, and optimizers
G_student = GeneratorStudent(3).to(device)
opt_G_student = optim.Adam(G_student.parameters(), lr=0.0002, betas=(0.5, 0.999))
# Discriminators and their optimizers
DA = Discriminator(3).to(device)
DB = Discriminator(3).to(device)
opt_DA = optim.Adam(DA.parameters(), lr=0.0002, betas=(0.5, 0.999))
opt_DB = optim.Adam(DB.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
num_epochs = 20
lambda_cycle = 11  # Weight for cycle consistency loss
lambda_identity = 7
for epoch in range(num_epochs):
    for batch in dataloader:
        painting = batch['painting'].to(device)
        sketch = batch['sketch'].to(device)

        # === Forward pass through the frozen teacher models ===
        with torch.no_grad():
            teacher_fake_sketch = G(painting, sketch)
            teacher_fake_painting = G(sketch, painting)

        # === Forward pass through the student model ===
        student_fake_sketch = G_student(painting, sketch)
        student_fake_painting = G_student(sketch, painting)

        # === Distillation Loss ===
        distillation_loss_sketch = distillation_loss(student_fake_sketch, teacher_fake_sketch)
        distillation_loss_painting = distillation_loss(student_fake_painting, teacher_fake_painting)
        total_distillation_loss = (distillation_loss_sketch + distillation_loss_painting) * lambda_distill

        # === Identity Loss for Student ===
        identity_painting = G_student(painting, sketch)
        loss_identity_painting = identity_loss(identity_painting, painting) * lambda_identity
        identity_sketch = G_student(sketch, painting)
        loss_identity_sketch = identity_loss(identity_sketch, sketch) * lambda_identity

        # === Adversarial Loss for Student ===
        pred_student_fake_sketch = DB(student_fake_sketch)
        loss_student_G_adv = adversarial_loss(pred_student_fake_sketch, torch.ones_like(pred_student_fake_sketch))
        pred_student_fake_painting = DA(student_fake_painting)
        loss_student_F_adv = adversarial_loss(pred_student_fake_painting, torch.ones_like(pred_student_fake_painting))

        # === Cycle Consistency Loss for Student ===
        reconstructed_student_painting = G_student(student_fake_sketch, student_fake_painting)
        loss_student_cycle_painting = cycle_loss(reconstructed_student_painting, painting) * lambda_cycle
        reconstructed_student_sketch = G_student(student_fake_painting, student_fake_sketch)
        loss_student_cycle_sketch = cycle_loss(reconstructed_student_sketch, sketch) * lambda_cycle

        # === Total Loss for Student Generator ===
        loss_G_student_total = (
            loss_identity_painting + loss_identity_sketch +
            loss_student_G_adv + loss_student_F_adv +
            loss_student_cycle_painting + loss_student_cycle_sketch +
            total_distillation_loss
        )

        # === Update Student Generator ===
        opt_G_student.zero_grad()
        loss_G_student_total.backward()
        opt_G_student.step()

        # === Train Discriminators (DA, DB) ===
        pred_real_painting = DA(painting)
        loss_DA_real = adversarial_loss(pred_real_painting, torch.ones_like(pred_real_painting))
        pred_fake_painting = DA(student_fake_painting.detach())
        loss_DA_fake = adversarial_loss(pred_fake_painting, torch.zeros_like(pred_fake_painting))
        loss_DA = (loss_DA_real + loss_DA_fake) * 0.5

        pred_real_sketch = DB(sketch)
        loss_DB_real = adversarial_loss(pred_real_sketch, torch.ones_like(pred_real_sketch))
        pred_fake_sketch = DB(student_fake_sketch.detach())
        loss_DB_fake = adversarial_loss(pred_fake_sketch, torch.zeros_like(pred_fake_sketch))
        loss_DB = (loss_DB_real + loss_DB_fake) * 0.5

        # Update Discriminators
        opt_DA.zero_grad()
        opt_DB.zero_grad()
        loss_DA.backward()
        loss_DB.backward()
        opt_DA.step()
        opt_DB.step()

        print(f"Epoch [{epoch}/{num_epochs}], Loss G_Student_Total: {loss_G_student_total.item()}, Loss DA: {loss_DA.item()}, Loss DB: {loss_DB.item()}")

    print(f'Epoch {epoch} done')
print('Training done')

# %% [markdown]
# ##epochs ~19 to ~7 loss drop with MSE Loss
#
# ##Next phase test out KLDiv loss

# %% [markdown]
# #G loss seems to be dropping by 1 per epoch, progress!
# AdaIN could be the reason
#
# or Identity Loss
#
#
# #D loss non-existant,
# batch size (8) too small?
#
# Learning rate (0.0002) too high?
#
# Hovers around ~0.2... ~

# %% [markdown]
# ##Parent

# %%
ep = load_checkpoint(G, G_sketch, DA, DB, opt_G, opt_G_sketch, opt_DA, opt_DB, "/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_67.pth")

# %%
start_epoch = load_checkpoint(G, G_sketch, DA, DB, opt_G, opt_G_sketch, opt_DA, opt_DB, "/content/drive/MyDrive/SavedEpochs/checkpoint_epoch_76.pth")

def load_image(image_path, img_size=128):
    image = Image.open(image_path).convert("RGB")
    transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    return transform(image).unsqueeze(0)


test_image_path = "/content/danbooru-sketch-pair-128x/color/src/0000/100000.png"
test_image = load_image(test_image_path).to(device)


test_image_path2 = "/content/danbooru-sketch-pair-128x/color/sketch/0000/1001000.png"
test_image2 = load_image(test_image_path2).to(device)


G.eval()  # evaluation mode
with torch.no_grad():
    generated_image = G(test_image, test_image2)

#
generated_image = generated_image.squeeze().cpu().numpy().transpose(1, 2, 0)
plt.imshow((generated_image + 1) / 2)  # [-1, 1] range to [0, 1]
#plt.imshow(generated_image)
plt.show()

# %% [markdown]
# ##Student

# %%
def load_image(image_path, img_size=128):
    image = Image.open(image_path).convert("RGB")
    transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    return transform(image).unsqueeze(0)


test_image_path = "/content/drive/MyDrive/input/327.jpg"
test_image = load_image(test_image_path).to(device)


test_image_path2 = "/content/drive/MyDrive/output/350.jpg"
test_image2 = load_image(test_image_path2).to(device)


G_student.eval()  # evaluation mode
with torch.no_grad():
    generated_image = G_student(test_image, test_image2)

#
generated_image = generated_image.squeeze().cpu().numpy().transpose(1, 2, 0)
plt.imshow((generated_image + 1) / 2)  # [-1, 1] range to [0, 1]
#plt.imshow(generated_image)
plt.show()

# %% [markdown]
# # Style Transfer is not happening!
